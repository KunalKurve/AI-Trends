# %% [markdown]
# # Loading CSV into DataFrame
#
# - In the previous exercise, you have seen a method of creating DataFrame but generally, loading data from CSV file is the most common method of creating DataFrames. In this exercise, you'll create a PySpark DataFrame from a `people.csv` file that is already provided to you as a `file_path` and confirm the created object is a PySpark DataFrame.
#
# - Remember, you already have `SparkSession` `spark` and `file_path` variable (which is the path to the `people.csv` file) available in your workspace..

# %% [markdown]
# ## Instructions
#
# - Create a DataFrame from `file_path` variable which is the path to the `people.csv` file.
# - Confirm the output as PySpark DataFrame.

# %%
# Intialization
import os
import sys

os.environ["SPARK_HOME"] = "/home/talentum/spark"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
# In below two lines, use /usr/bin/python2.7 if you want to use Python 2
os.environ["PYSPARK_PYTHON"] = "/usr/bin/python3.6" 
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/bin/python3"
sys.path.insert(0, os.environ["PYLIB"] +"/py4j-0.10.7-src.zip")
sys.path.insert(0, os.environ["PYLIB"] +"/pyspark.zip")

# NOTE: Whichever package you want mention here.
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0 pyspark-shell' 
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.3 pyspark-shell'
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'

# %%
#Entrypoint 2.x
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark SQL basic example").enableHiveSupport().getOrCreate()

# On yarn:
# spark = SparkSession.builder.appName("Spark SQL basic example").enableHiveSupport().master("yarn").getOrCreate()
# specify .master("yarn")

sc = spark.sparkContext

# %%
file_path = "file:///home/talentum/test-jupyter/P2/M1/SM8/Dataset/people.csv"

# Create an DataFrame from file_path
people_df = spark.read.csv(file_path, header=True, inferSchema=True)

# Check the type of people_df
print("The type of people_df is", type(people_df))
# Out:
# The type of people_df is <class 'pyspark.sql.dataframe.DataFrame'>

# %%
people_df.collect()
# Out:
# [Row(_c0=0, person_id=100, name='Penelope Lewis', sex='female', date of birth='1990-08-31'),
#  Row(_c0=1, person_id=101, name='David Anthony', sex='male', date of birth='1971-10-14'),
#  Row(_c0=2, person_id=102, name='Ida Shipp', sex='female', date of birth='1962-05-24'),
#  Row(_c0=3, person_id=103, name='Joanna Moore', sex='female', date of birth='2017-03-10'),
#  Row(_c0=4, person_id=104, name='Lisandra Ortiz', sex='female', date of birth='2020-08-05'),
#  Row(_c0=5, person_id=105, name='David Simmons', sex='male', date of birth='1999-12-30'),
#  Row(_c0=6, person_id=106, name='Edward Hudson', sex='male', date of birth='1983-05-09'),
#  Row(_c0=7, person_id=107, name='Albert Jones', sex='male', date of birth='1990-09-13'),
#  Row(_c0=8, person_id=108, name='Leonard Cavender', sex='male', date of birth='1958-08-08'),
#  Row(_c0=9, person_id=109, name='Everett Vadala', sex='male', date of birth='2005-05-24'),
#  Row(_c0=10, person_id=110, name='Freddie Claridge', sex='male', date of birth='2002-05-07'),
#  Row(_c0=11, person_id=111, name='Annabelle Rosseau', sex='female', date of birth='1989-07-13'),
#  Row(_c0=12, person_id=112, name='Eulah Emanuel', sex='female', date of birth='1976-01-19'),
#  Row(_c0=13, person_id=113, name='Shaun Love', sex='male', date of birth='1970-05-26'),
#  Row(_c0=14, person_id=114, name='Alejandro Brennan', sex='male', date of birth='1980-12-22'),
#  Row(_c0=15, person_id=115, name='Robert Mcreynolds', sex='male', date of birth='1973-12-27'),
#  Row(_c0=16, person_id=116, name='Carla Spickard', sex='female', date of birth='1985-06-13'),
#  Row(_c0=17, person_id=117, name='Florence Eberhart', sex='female', date of birth='2024-06-01'),
#  Row(_c0=18, person_id=118, name='Tina Gaskins', sex='female', date of birth='1966-12-05'),
#  Row(_c0=19, person_id=119, name='Florence Mulhern', sex='female', date of birth='1959-05-31'),
#  Row(_c0=20, person_id=120, name='Joel Smith', sex='male', date of birth='1996-08-13'),
#  Row(_c0=21, person_id=121, name='Evelyn Kriner', sex='female', date of birth='1978-09-16'),
#  Row(_c0=22, person_id=122, name='Heather Luce', sex='female', date of birth='2012-02-24'),
#  Row(_c0=23, person_id=123, name='Angel Moher', sex='male', date of birth='2017-12-22'),
#  Row(_c0=24, person_id=124, name='Charles Leonard', sex='male', date of birth='1972-03-09'),
#  Row(_c0=25, person_id=125, name='Mark Miller', sex='male', date of birth='1976-05-11'),
#  Row(_c0=26, person_id=126, name='Marion Baca', sex='female', date of birth='1948-03-04'),
#  Row(_c0=27, person_id=127, name='Devona Kay', sex='female', date of birth='2009-12-30'),
#  Row(_c0=28, person_id=128, name='Betty Endicott', sex='female', date of birth='1992-05-01'),
#  Row(_c0=29, person_id=129, name='David Bishop', sex='male', date of birth='1960-10-18'),
#  Row(_c0=30, person_id=130, name='Jane Ross', sex='female', date of birth='1965-09-12'),
#  Row(_c0=31, person_id=131, name='Joseph Windus', sex='male', date of birth='2029-05-27'),
#  Row(_c0=32, person_id=132, name='Christopher Gilbert', sex='male', date of birth='2010-09-21'),
#  Row(_c0=33, person_id=133, name='Robert Salisbury', sex='male', date of birth='1965-06-22'),
#  Row(_c0=34, person_id=134, name='Pauline Steele', sex='female', date of birth='1969-10-18'),
#  Row(_c0=35, person_id=135, name='Anne Novotny', sex='female', date of birth='1936-02-18'),
#  Row(_c0=36, person_id=136, name='Wilbert Glass', sex='male', date of birth='1976-10-10'),
#  Row(_c0=37, person_id=137, name='Carol Noble', sex='female', date of birth='1997-02-11'),
#  Row(_c0=38, person_id=138, name='Constance Fulmer', sex='female', date of birth='2004-03-07'),
#  Row(_c0=39, person_id=139, name='Renee Simon', sex='female', date of birth='1995-10-29'),
#  Row(_c0=40, person_id=140, name='Juan Dunn', sex='male', date of birth='1969-10-06'),
#  Row(_c0=41, person_id=141, name='Kristie Price', sex='female', date of birth='2021-05-29'),
#  Row(_c0=42, person_id=142, name='Thomas Nichols', sex='male', date of birth='1988-09-04'),
#  Row(_c0=43, person_id=143, name='Kimberly Harms', sex='female', date of birth='1979-06-28'),
#  Row(_c0=44, person_id=144, name='Lyle Murray', sex='male', date of birth='2021-10-16'),
#  Row(_c0=45, person_id=145, name='Michele Stephens', sex='female', date of birth='2005-09-27'),
#  Row(_c0=46, person_id=146, name='Lee Finney', sex='male', date of birth='1976-10-21'),
#  Row(_c0=47, person_id=147, name='Michael Coffin', sex='male', date of birth='1983-01-14'),
#  Row(_c0=48, person_id=148, name='Martha Jordan', sex='female', date of birth='1987-08-23'),
#  Row(_c0=49, person_id=149, name='Corinne Hansen', sex='female', date of birth='1969-08-29'),
#  Row(_c0=50, person_id=150, name='Drew Rowe', sex='male', date of birth='1983-08-20'),
#  Row(_c0=51, person_id=151, name='Margaret Belk', sex='female', date of birth='1962-01-11'),
#  Row(_c0=52, person_id=152, name='Michael Swihart', sex='male', date of birth='1957-05-05'),
#  Row(_c0=53, person_id=153, name='Robin Mercado', sex='male', date of birth='2002-12-10'),
#  Row(_c0=54, person_id=154, name='Sharon Hoover', sex='female', date of birth='1976-03-22'),
#  Row(_c0=55, person_id=155, name='Nancy Heinrich', sex='female', date of birth='2001-03-27'),
#  Row(_c0=56, person_id=156, name='Enrique Carney', sex='male', date of birth='1996-09-16'),
#  Row(_c0=57, person_id=157, name='Harold Hicks', sex='male', date of birth='2022-11-21'),
#  Row(_c0=58, person_id=158, name='Tristan Myatt', sex='male', date of birth='1990-12-26'),
#  Row(_c0=59, person_id=159, name='Eva Erickson', sex='female', date of birth='1958-05-02'),
#  Row(_c0=60, person_id=160, name='Scott Phillips', sex='male', date of birth='1967-05-22'),
#  Row(_c0=61, person_id=161, name='Israel Welchel', sex='male', date of birth='1974-11-08'),
#  Row(_c0=62, person_id=162, name='Victoria Bobo', sex='female', date of birth='1981-02-28'),
#  Row(_c0=63, person_id=163, name='Bette Stones', sex='female', date of birth='2003-09-17'),
#  Row(_c0=64, person_id=164, name='Reed Henderson', sex='male', date of birth='2023-03-10'),
#  Row(_c0=65, person_id=165, name='Betty Weitz', sex='female', date of birth='2023-12-17'),
#  Row(_c0=66, person_id=166, name='John Hilton', sex='male', date of birth='1954-03-14'),
#  Row(_c0=67, person_id=167, name='John Roberts', sex='male', date of birth='1995-08-24'),
#  Row(_c0=68, person_id=168, name='Rebecca Segura', sex='female', date of birth='1993-05-17'),
#  Row(_c0=69, person_id=169, name='Leonarda Johnson', sex='female', date of birth='2006-06-01'),
#  Row(_c0=70, person_id=170, name='William Nash', sex='male', date of birth='1996-10-14'),
#  Row(_c0=71, person_id=171, name='Devora Jurado', sex='female', date of birth='1970-09-26'),
#  Row(_c0=72, person_id=172, name='Lenny Hossack', sex=None, date of birth='1989-05-09'),
#  Row(_c0=73, person_id=173, name='Regina Lamb', sex='female', date of birth='1977-07-22'),
#  Row(_c0=74, person_id=174, name='Cara Merlette', sex='female', date of birth='2006-05-11'),
#  Row(_c0=75, person_id=175, name='Debra Clark', sex='female', date of birth='2015-01-06'),
#  Row(_c0=76, person_id=176, name='Anita Rayome', sex='female', date of birth='2011-08-24'),
#  Row(_c0=77, person_id=177, name='Frances Myers', sex='female', date of birth='1999-09-25'),
#  Row(_c0=78, person_id=178, name='Roy Marinello', sex='male', date of birth='1986-09-05'),
#  Row(_c0=79, person_id=179, name='Dorothy Just', sex='female', date of birth='1988-11-26'),
#  Row(_c0=80, person_id=180, name='Sherry Zepeda', sex='female', date of birth='1968-02-15'),
#  Row(_c0=81, person_id=181, name='Michael Morris', sex='male', date of birth='1998-11-18'),
#  Row(_c0=82, person_id=182, name='Cynthia Aste', sex='female', date of birth='1972-12-08'),
#  Row(_c0=83, person_id=183, name='Lawrence Russi', sex='male', date of birth='1968-07-07'),
#  Row(_c0=84, person_id=184, name='Margaret Alford', sex='female', date of birth='2011-01-31'),
#  Row(_c0=85, person_id=185, name='Paula Evans', sex='female', date of birth='1909-02-10'),
#  Row(_c0=86, person_id=186, name='Retha Fisher', sex='female', date of birth='1955-03-14'),
#  Row(_c0=87, person_id=187, name='Karen Stoker', sex='female', date of birth='1960-09-15'),
#  Row(_c0=88, person_id=188, name='Manuel Oday', sex='male', date of birth='1996-10-16'),
#  Row(_c0=89, person_id=189, name='Richard Berryman', sex='male', date of birth='1972-09-10'),
#  Row(_c0=90, person_id=190, name='Lisa Barth', sex='female', date of birth='1961-12-22'),
#  Row(_c0=91, person_id=191, name='Barbara Coffelt', sex='female', date of birth='2016-12-28'),
#  Row(_c0=92, person_id=192, name='Marilyn Nguyen', sex='female', date of birth='2008-06-13'),
#  Row(_c0=93, person_id=193, name='Marianne Hier', sex='female', date of birth='1972-10-26'),
#  Row(_c0=94, person_id=194, name='Mary Church', sex='female', date of birth='1981-05-24'),
#  Row(_c0=95, person_id=195, name='Michael Ludgate', sex='male', date of birth='1973-10-23'),
#  Row(_c0=96, person_id=196, name='Jerry Wilson', sex='male', date of birth='1985-03-29'),
#  Row(_c0=97, person_id=197, name='Kathryn White', sex='female', date of birth='1988-09-05'),
#  Row(_c0=98, person_id=198, name='Carolyn Douglas', sex='female', date of birth='1986-09-27'),
#  Row(_c0=99, person_id=199, name='Thomas Mccorkle', sex='male', date of birth='1972-03-02'),
#  Row(_c0=100, person_id=200, name='David Situ', sex='male', date of birth='1978-04-22'),
#  Row(_c0=101, person_id=201, name='Frederick Hall', sex='male', date of birth='1983-12-15'),
#  Row(_c0=102, person_id=202, name='Mark Thomas', sex='male', date of birth='1973-04-03'),
#  Row(_c0=103, person_id=203, name='Yvette Lombardo', sex='female', date of birth='2021-06-14'),
#  Row(_c0=104, person_id=204, name='Melanie Lahip', sex=None, date of birth='1967-01-04'),
#  Row(_c0=105, person_id=205, name='Timothy Glenn', sex='male', date of birth='1982-10-31'),
#  Row(_c0=106, person_id=206, name='Michael Sauls', sex='male', date of birth='1966-07-20'),
#  Row(_c0=107, person_id=207, name='Wiley Cota', sex='male', date of birth='1977-12-31'),
#  Row(_c0=108, person_id=208, name='Pamela Brawley', sex='female', date of birth='1977-10-15'),
#  Row(_c0=109, person_id=209, name='James Quintero', sex='male', date of birth='1973-02-16'),
#  Row(_c0=110, person_id=210, name='Deborah Gerena', sex='female', date of birth='2001-11-18'),
#  Row(_c0=111, person_id=211, name='Dale Kroll', sex='female', date of birth='1953-12-18'),
#  Row(_c0=112, person_id=212, name='Wanda Balderrama', sex='female', date of birth='1937-04-14'),
#  Row(_c0=113, person_id=213, name='Roberta Tara', sex='female', date of birth='1976-08-20'),
#  Row(_c0=114, person_id=214, name='Mary Mininger', sex='female', date of birth='1999-07-03'),
#  Row(_c0=115, person_id=215, name='Michael Fields', sex='male', date of birth='1982-12-23'),
#  Row(_c0=116, person_id=216, name='Michael Patterson', sex='male', date of birth='1986-10-31'),
#  Row(_c0=117, person_id=217, name='Sally Chiarito', sex='female', date of birth='1969-01-20'),
#  Row(_c0=118, person_id=218, name='David Griffin', sex='male', date of birth='1979-09-18'),
#  Row(_c0=119, person_id=219, name='Michael Kinsler', sex='male', date of birth='1947-01-29'),
#  Row(_c0=120, person_id=220, name='Denita Bennett', sex='female', date of birth='1965-08-22'),
#  Row(_c0=121, person_id=221, name='David Roode', sex='male', date of birth='20175-02-28'),
#  Row(_c0=122, person_id=222, name='Bennie Taylor', sex='male', date of birth='2024-03-13'),
#  Row(_c0=123, person_id=223, name='Gordon Hughes', sex='male', date of birth='2031-08-10'),
#  Row(_c0=124, person_id=224, name='Gloria Davis', sex='female', date of birth='2004-03-01'),
#  Row(_c0=125, person_id=225, name='Shirley Brown', sex='female', date of birth='1983-04-27'),
#  Row(_c0=126, person_id=226, name='Gracie Hannah', sex='female', date of birth='1948-08-07'),
#  Row(_c0=127, person_id=227, name='Robert Nunes', sex='male', date of birth='1965-03-10'),
#  Row(_c0=128, person_id=228, name='Virginia Stevens', sex='female', date of birth='2009-02-24'),
#  Row(_c0=129, person_id=229, name='Casey Angel', sex='female', date of birth='1943-05-28'),
#  Row(_c0=130, person_id=230, name='Sabrina Metzger', sex='female', date of birth='2019-12-21'),
#  Row(_c0=131, person_id=231, name='Ginny Papik', sex='female', date of birth='1960-01-08'),
#  Row(_c0=132, person_id=232, name='Homer Bowman', sex='male', date of birth='1979-10-03'),
#  Row(_c0=133, person_id=233, name='Andrew Childers', sex='male', date of birth='1956-03-09'),
#  Row(_c0=134, person_id=234, name='Linda Lares', sex='female', date of birth='2015-12-26'),
#  Row(_c0=135, person_id=235, name='Alexander Jones', sex='male', date of birth='1995-05-23'),
#  Row(_c0=136, person_id=236, name='Yessenia Uhrig', sex='female', date of birth='1993-06-28'),
#  Row(_c0=137, person_id=237, name='Marilyn Scott', sex='female', date of birth='1987-06-09'),
#  Row(_c0=138, person_id=238, name='Tanya Wilkins', sex='female', date of birth='2012-05-19'),
#  Row(_c0=139, person_id=239, name='Gary Bloxom', sex='male', date of birth='1973-05-07'),
#  Row(_c0=140, person_id=240, name='Ernesto Henning', sex='male', date of birth='2012-06-29'),
#  Row(_c0=141, person_id=241, name='Terrence Kruger', sex='male', date of birth='1978-01-01'),
#  Row(_c0=142, person_id=242, name='Pablo Hardman', sex='male', date of birth='1982-09-02'),
#  Row(_c0=143, person_id=243, name='Mark Nealy', sex='male', date of birth='2008-10-04'),
#  Row(_c0=144, person_id=244, name='Jami Carroll', sex='female', date of birth='2001-04-10'),
#  Row(_c0=145, person_id=245, name='Ian Snyder', sex='male', date of birth='1968-01-06'),
#  Row(_c0=146, person_id=246, name='Monica Lewis', sex='female', date of birth='1995-02-06'),
#  Row(_c0=147, person_id=247, name='Brenda Morgan', sex='female', date of birth='1982-12-28'),
#  Row(_c0=148, person_id=248, name='Angela Enyart', sex='female', date of birth='1950-03-14'),
#  Row(_c0=149, person_id=249, name='Frances Anderson', sex='female', date of birth='1989-10-09'),
#  Row(_c0=150, person_id=250, name='Nell Smith', sex='female', date of birth='1950-03-18'),
#  Row(_c0=151, person_id=251, name='David Whitlock', sex='male', date of birth='1979-01-18'),
#  Row(_c0=152, person_id=252, name='Earlean Weaver', sex='female', date of birth='1981-07-03'),
#  Row(_c0=153, person_id=253, name='Roger Mckinney', sex='male', date of birth='1960-11-01'),
#  Row(_c0=154, person_id=254, name='Hilda Mannino', sex='female', date of birth='2013-06-15'),
#  Row(_c0=155, person_id=255, name='Norman Sunderland', sex='male', date of birth='1991-05-29'),
#  Row(_c0=156, person_id=256, name='Jennifer Mcanally', sex='female', date of birth='1981-08-13'),
#  Row(_c0=157, person_id=257, name='Carl Matz', sex='male', date of birth='20175-02-28'),
#  Row(_c0=158, person_id=258, name='Sheila Roades', sex='female', date of birth='1991-08-30'),
#  Row(_c0=159, person_id=259, name='Lisa Young', sex='female', date of birth='1993-05-15'),
#  Row(_c0=160, person_id=260, name='Larry Sturgill', sex='male', date of birth='1986-05-11'),
#  Row(_c0=161, person_id=261, name='Barbara Hallaway', sex='female', date of birth='1957-07-09'),
#  Row(_c0=162, person_id=262, name='Ruth Melero', sex='female', date of birth='1980-08-23'),
#  Row(_c0=163, person_id=263, name='Anthony Hampton', sex='male', date of birth='1988-08-23'),
#  Row(_c0=164, person_id=264, name='Clair Malone', sex='male', date of birth='2017-10-15'),
#  Row(_c0=165, person_id=265, name='John Jentzsch', sex='male', date of birth='1998-12-06'),
#  Row(_c0=166, person_id=266, name='Lee Ashley', sex='male', date of birth='2005-09-03'),
#  Row(_c0=167, person_id=267, name='Mildred Murphy', sex='female', date of birth='1992-08-23'),
#  Row(_c0=168, person_id=268, name='Lonnie Barton', sex='male', date of birth='1944-04-05'),
#  Row(_c0=169, person_id=269, name='Jacqueline Berger', sex='female', date of birth='2007-08-29'),
#  Row(_c0=170, person_id=270, name='John Barnard', sex='male', date of birth='2015-07-31'),
#  Row(_c0=171, person_id=271, name='Marc Danker', sex='male', date of birth='1991-03-12'),
#  Row(_c0=172, person_id=272, name='Joseph Baldwin', sex='male', date of birth='1948-01-15'),
#  Row(_c0=173, person_id=273, name='Mark Kidd', sex='male', date of birth='1977-12-11'),
#  Row(_c0=174, person_id=274, name='Clark Tillson', sex='male', date of birth='1954-02-24'),
#  Row(_c0=175, person_id=275, name='James Fields', sex='male', date of birth='1992-09-08'),
#  Row(_c0=176, person_id=276, name='Daniel Fenner', sex='male', date of birth='20175-02-28'),
#  Row(_c0=177, person_id=277, name='Daniel Mercer', sex='male', date of birth='2020-10-24'),
#  Row(_c0=178, person_id=278, name='Spencer Layland', sex='male', date of birth='1971-07-22'),
#  Row(_c0=179, person_id=279, name='Karla Headrick', sex='female', date of birth='1994-08-21'),
#  Row(_c0=180, person_id=280, name='Linda Grant', sex='female', date of birth='1995-07-14'),
#  Row(_c0=181, person_id=281, name='Lorraine Sanders', sex='female', date of birth='2033-03-09'),
#  Row(_c0=182, person_id=282, name='Cedric White', sex='male', date of birth='1967-09-14'),
#  Row(_c0=183, person_id=283, name='Lidia Benson', sex='female', date of birth='1965-09-19'),
#  Row(_c0=184, person_id=284, name='Patricia Carden', sex='female', date of birth='2004-11-25'),
#  Row(_c0=185, person_id=285, name='David Robertson', sex='male', date of birth='1959-06-19'),
#  Row(_c0=186, person_id=286, name='William Manns', sex='male', date of birth='1956-10-16'),
#  Row(_c0=187, person_id=287, name='Melissa Colanero', sex='female', date of birth='1988-02-06'),
#  Row(_c0=188, person_id=288, name='Harold Demarco', sex='male', date of birth='1978-01-15'),
#  Row(_c0=189, person_id=289, name='Randall Morris', sex='male', date of birth='1991-04-28'),
#  Row(_c0=190, person_id=290, name='Sarah Aucoin', sex='female', date of birth='1981-05-20'),
#  Row(_c0=191, person_id=291, name='Kelvin Poche', sex='male', date of birth='1988-05-11'),
#  Row(_c0=192, person_id=292, name='Peter Horne', sex='male', date of birth='1959-09-07'),
#  Row(_c0=193, person_id=293, name='Jose Gage', sex='male', date of birth='1993-01-29'),
#  Row(_c0=194, person_id=294, name='Danny Cortez', sex='male', date of birth='2037-11-10'),
#  Row(_c0=195, person_id=295, name='Jennifer Richardson', sex='female', date of birth='1993-04-10'),
#  Row(_c0=196, person_id=296, name='Dominick Johnson', sex='male', date of birth='1975-05-14'),
#  Row(_c0=197, person_id=297, name='Ronald Elliott', sex='male', date of birth='1992-01-14'),
#  Row(_c0=198, person_id=298, name='Velma Hamilton', sex='female', date of birth='1978-11-23'),
#  Row(_c0=199, person_id=299, name='Marlene Morger', sex='female', date of birth='1994-05-22'),
#  Row(_c0=200, person_id=300, name='Scott Brown', sex='male', date of birth='1985-04-04'),
#  Row(_c0=201, person_id=301, name='Cindy Johnson', sex='female', date of birth='1985-08-22'),
#  Row(_c0=202, person_id=302, name='Michael Martinez', sex='male', date of birth='1963-06-16'),
#  Row(_c0=203, person_id=303, name='Earle Hardy', sex='male', date of birth='2001-06-22'),
#  Row(_c0=204, person_id=304, name='Tommy Harris', sex='male', date of birth='1965-09-25'),
#  Row(_c0=205, person_id=305, name='Edmond Ayres', sex='male', date of birth='1977-05-05'),
#  Row(_c0=206, person_id=306, name='Jose Alvarez', sex='male', date of birth='2013-12-21'),
#  Row(_c0=207, person_id=307, name='Charles Rendon', sex='male', date of birth='1980-01-19'),
#  Row(_c0=208, person_id=308, name='Lisa Humphrey', sex='female', date of birth='1955-02-12'),
#  Row(_c0=209, person_id=309, name='Raymond Patel', sex='male', date of birth='2011-07-22'),
#  Row(_c0=210, person_id=310, name='Regina Bartley', sex='female', date of birth='1990-12-29'),
#  Row(_c0=211, person_id=311, name='Harold Gamble', sex='male', date of birth='1984-05-04'),
#  Row(_c0=212, person_id=312, name='Joseph Sharp', sex='male', date of birth='1997-11-29'),
#  Row(_c0=213, person_id=313, name='Elizabeth Jacobsen', sex='female', date of birth='1960-10-24'),
#  Row(_c0=214, person_id=314, name='Allison Bailly', sex='female', date of birth='1983-07-25'),
#  Row(_c0=215, person_id=315, name='Bobby Tibbs', sex='male', date of birth='1977-01-07'),
#  Row(_c0=216, person_id=316, name='Walker Ritchie', sex='male', date of birth='1968-01-05'),
#  Row(_c0=217, person_id=317, name='Mason Fernandez', sex='male', date of birth='1969-03-14'),
#  Row(_c0=218, person_id=318, name='Joshua Williams', sex='male', date of birth='1990-08-17'),
#  Row(_c0=219, person_id=319, name='Marlene Phillips', sex='female', date of birth='2005-01-26'),
#  Row(_c0=220, person_id=320, name='Woodrow Barton', sex='male', date of birth='1973-12-22'),
#  Row(_c0=221, person_id=321, name='Kenneth Buchanan', sex='male', date of birth='1974-02-15'),
#  Row(_c0=222, person_id=322, name='Michelle Lopez', sex='female', date of birth='1984-09-23'),
#  Row(_c0=223, person_id=323, name='Terry Kellems', sex='male', date of birth='1967-04-02'),
#  Row(_c0=224, person_id=324, name='Richard Burns', sex='male', date of birth='1988-06-16'),
#  Row(_c0=225, person_id=325, name='Michelle Antczak', sex='female', date of birth='1962-08-07'),
#  Row(_c0=226, person_id=326, name='Matthew Pittman', sex='male', date of birth='1978-05-27'),
#  Row(_c0=227, person_id=327, name='Dawn Bryer', sex='female', date of birth='1970-02-26'),
#  Row(_c0=228, person_id=328, name='Jessica Mcmullen', sex='female', date of birth='1960-04-12'),
#  Row(_c0=229, person_id=329, name='Lesley Nelson', sex='female', date of birth='1967-09-03'),
#  Row(_c0=230, person_id=330, name='Harold Christian', sex='male', date of birth='1985-08-02'),
#  Row(_c0=231, person_id=331, name='Dwayne Barstow', sex='male', date of birth='2003-12-05'),
#  Row(_c0=232, person_id=332, name='Thomas Ennis', sex='male', date of birth='1979-09-18'),
#  Row(_c0=233, person_id=333, name='Pamela Matley', sex='female', date of birth='1992-10-07'),
#  Row(_c0=234, person_id=334, name='Rose Smith', sex='female', date of birth='1964-05-16'),
#  Row(_c0=235, person_id=335, name='Jo George', sex='female', date of birth='1958-12-15'),
#  Row(_c0=236, person_id=336, name='Alfred Carmichael', sex='male', date of birth='1972-03-10'),
#  Row(_c0=237, person_id=337, name='Cheryl Collette', sex='female', date of birth='1951-05-26'),
#  Row(_c0=238, person_id=338, name='Jeanne Wimberly', sex='female', date of birth='1968-09-22'),
#  Row(_c0=239, person_id=339, name='Robert Worrell', sex='male', date of birth='1982-07-20'),
#  Row(_c0=240, person_id=340, name='Carrie Hilburn', sex='female', date of birth='2025-08-18'),
#  Row(_c0=241, person_id=341, name='Bailey Burrow', sex='female', date of birth='1946-02-21'),
#  Row(_c0=242, person_id=342, name='Brenda Camarena', sex='female', date of birth='2005-04-30'),
#  Row(_c0=243, person_id=343, name='Joshua Harris', sex='male', date of birth='2016-01-04'),
#  Row(_c0=244, person_id=344, name='Norma Ashley', sex='female', date of birth='1979-01-28'),
#  Row(_c0=245, person_id=345, name='Dawn Galindo', sex='female', date of birth='1996-06-10'),
#  Row(_c0=246, person_id=346, name='Randy Sigg', sex='male', date of birth='1975-03-09'),
#  Row(_c0=247, person_id=347, name='Dorothy Piatek', sex='female', date of birth='1963-03-09'),
#  Row(_c0=248, person_id=348, name='Charles Hilton', sex='male', date of birth='1977-01-31'),
#  Row(_c0=249, person_id=349, name='Brandon Satterwhite', sex='male', date of birth='1976-03-25'),
#  Row(_c0=250, person_id=350, name='Roscoe Green', sex='male', date of birth='1943-08-18'),
#  Row(_c0=251, person_id=351, name='James Vantull', sex='male', date of birth='1971-04-10'),
#  Row(_c0=252, person_id=352, name='Louis Torres', sex='male', date of birth='2004-09-10'),
#  Row(_c0=253, person_id=353, name='Adam Strobeck', sex='male', date of birth='1941-01-10'),
#  Row(_c0=254, person_id=354, name='Adam East', sex='male', date of birth='1993-06-14'),
#  Row(_c0=255, person_id=355, name='Sharlene Connolly', sex='female', date of birth='1977-01-03'),
#  Row(_c0=256, person_id=356, name='Alma Johannes', sex='female', date of birth='1992-03-25'),
#  Row(_c0=257, person_id=357, name='Patty Byers', sex='female', date of birth='1992-04-04'),
#  Row(_c0=258, person_id=358, name='Nancy Nakata', sex='female', date of birth='1970-02-17'),
#  Row(_c0=259, person_id=359, name='Rhonda Applegate', sex='female', date of birth='1962-09-13'),
#  Row(_c0=260, person_id=360, name='William Stevenson', sex='male', date of birth='1977-01-26'),
#  Row(_c0=261, person_id=361, name='Jacob Craver', sex='male', date of birth='1985-06-06'),
#  Row(_c0=262, person_id=362, name='Steven Hayton', sex='male', date of birth='1995-09-08'),
#  Row(_c0=263, person_id=363, name='Willie Lawrence', sex='male', date of birth='1958-08-01'),
#  Row(_c0=264, person_id=364, name='Theodore Walker', sex='male', date of birth='1978-05-10'),
#  Row(_c0=265, person_id=365, name='Ronald Wilson', sex='male', date of birth='1965-04-09'),
#  Row(_c0=266, person_id=366, name='Diana Nesbitt', sex='female', date of birth='2026-04-27'),
#  Row(_c0=267, person_id=367, name='James Dixon', sex='male', date of birth='1944-06-15'),
#  Row(_c0=268, person_id=368, name='Zana Warren', sex='female', date of birth='1976-09-01'),
#  Row(_c0=269, person_id=369, name='Janette Broussard', sex='female', date of birth='2005-06-17'),
#  Row(_c0=270, person_id=370, name='Jesus Karr', sex='male', date of birth='1981-04-19'),
#  Row(_c0=271, person_id=371, name='Stanley Yates', sex='male', date of birth='1983-12-01'),
#  Row(_c0=272, person_id=372, name='Arthur Smith', sex='male', date of birth='1963-01-02'),
#  Row(_c0=273, person_id=373, name='Clyde Holohan', sex='male', date of birth='1956-08-22'),
#  Row(_c0=274, person_id=374, name='Michael Valdez', sex='male', date of birth='1996-11-13'),
#  Row(_c0=275, person_id=375, name='Dennis Lamas', sex='male', date of birth='1972-11-15'),
#  Row(_c0=276, person_id=376, name='Theresa Garner', sex='female', date of birth='2022-07-05'),
#  Row(_c0=277, person_id=377, name='Richard Mcdaniel', sex='male', date of birth='1966-09-01'),
#  Row(_c0=278, person_id=378, name='Anderson Bushman', sex='male', date of birth='1969-06-29'),
#  Row(_c0=279, person_id=379, name='Foster Nellis', sex='male', date of birth='1975-07-31'),
#  Row(_c0=280, person_id=380, name='Easter Rojas', sex='female', date of birth='1960-01-11'),
#  Row(_c0=281, person_id=381, name='Charles Powell', sex='male', date of birth='1974-01-08'),
#  Row(_c0=282, person_id=382, name='Joe Lagrone', sex='male', date of birth='1947-07-01'),
#  Row(_c0=283, person_id=383, name='Sandra May', sex='female', date of birth='1990-03-02'),
#  Row(_c0=284, person_id=384, name='Ronald Webb', sex='male', date of birth='1990-01-13'),
#  Row(_c0=285, person_id=385, name='Dorothy Bundy', sex='female', date of birth='1988-02-19'),
#  Row(_c0=286, person_id=386, name='Charlotte Gonzales', sex='female', date of birth='1964-02-02'),
#  Row(_c0=287, person_id=387, name='Bella Dickinson', sex='female', date of birth='1999-04-23'),
#  Row(_c0=288, person_id=388, name='Aaron Peterson', sex='male', date of birth='2007-11-06'),
#  Row(_c0=289, person_id=389, name='John Waters', sex='male', date of birth='1968-10-17'),
#  Row(_c0=290, person_id=390, name='Louis Sieja', sex=None, date of birth='1981-01-30'),
#  Row(_c0=291, person_id=391, name='Karen Westfall', sex='female', date of birth='1960-09-18'),
#  Row(_c0=292, person_id=392, name='Megan Lankford', sex='female', date of birth='1988-08-03'),
#  Row(_c0=293, person_id=393, name='Christopher Mccool', sex='male', date of birth='2016-10-09'),
#  Row(_c0=294, person_id=394, name='Brenda Fowler', sex='female', date of birth='1995-07-27'),
#  Row(_c0=295, person_id=395, name='Ryan Chinn', sex='male', date of birth='2000-10-14'),
#  Row(_c0=296, person_id=396, name='Elisha Hurt', sex='female', date of birth='1984-09-08'),
#  Row(_c0=297, person_id=397, name='Preston Carter', sex='male', date of birth='1993-10-20'),
#  Row(_c0=298, person_id=398, name='Louis Musick', sex='male', date of birth='1993-01-08'),
#  Row(_c0=299, person_id=399, name='Melanie Seaton', sex='female', date of birth='1972-04-20'),
#  Row(_c0=300, person_id=400, name='John Hewett', sex='male', date of birth='1976-12-10'),
#  Row(_c0=301, person_id=401, name='Grant Weston', sex='male', date of birth='2001-04-03'),
#  Row(_c0=302, person_id=402, name='Patricia Jones', sex='female', date of birth='1937-02-01'),
#  Row(_c0=303, person_id=403, name='Richard Weisenfluh', sex='male', date of birth='1992-05-12'),
#  Row(_c0=304, person_id=404, name='Ernest Warnock', sex='male', date of birth='1979-04-15'),
#  Row(_c0=305, person_id=405, name='Marion Hulse', sex=None, date of birth='1966-04-17'),
#  Row(_c0=306, person_id=406, name='Patrick Swope', sex='male', date of birth='1973-08-19'),
#  Row(_c0=307, person_id=407, name='Paul Plant', sex='male', date of birth='2033-10-11'),
#  Row(_c0=308, person_id=408, name='Norberto Lawrence', sex='male', date of birth='1992-03-06'),
#  Row(_c0=309, person_id=409, name='Jeffrey Steffensmeier', sex='male', date of birth='2001-08-30'),
#  Row(_c0=310, person_id=410, name='Patrick Luna', sex='male', date of birth='1979-08-19'),
#  Row(_c0=311, person_id=411, name='Donna Josephs', sex='female', date of birth='2002-01-09'),
#  Row(_c0=312, person_id=412, name='James Ross', sex='male', date of birth='2001-05-10'),
#  Row(_c0=313, person_id=413, name='Rhonda Milligan', sex='female', date of birth='1966-10-30'),
#  Row(_c0=314, person_id=414, name='Jack Heim', sex='female', date of birth='1948-11-06'),
#  Row(_c0=315, person_id=415, name='Sol Curry', sex='male', date of birth='2001-05-12'),
#  Row(_c0=316, person_id=416, name='Patricia Fuentes', sex='female', date of birth='1986-11-23'),
#  Row(_c0=317, person_id=417, name='Brian Goodrich', sex='male', date of birth='1972-04-11'),
#  Row(_c0=318, person_id=418, name='Victor Velasquez', sex='male', date of birth='1982-09-01'),
#  Row(_c0=319, person_id=419, name='Elizabeth Roark', sex='female', date of birth='1998-08-30'),
#  Row(_c0=320, person_id=420, name='Clifford Gabe', sex='male', date of birth='2000-01-03'),
#  Row(_c0=321, person_id=421, name='Desiree Green', sex='female', date of birth='1989-04-29'),
#  Row(_c0=322, person_id=422, name='Joseph Wilson', sex='male', date of birth='1960-09-02'),
#  Row(_c0=323, person_id=423, name='Monica Jackson', sex='female', date of birth='1986-12-18'),
#  Row(_c0=324, person_id=424, name='Martha Mason', sex='female', date of birth='1949-11-07'),
#  Row(_c0=325, person_id=425, name='Roy Weich', sex='male', date of birth='2006-02-15'),
#  Row(_c0=326, person_id=426, name='Bridget Davis', sex='female', date of birth='1977-02-03'),
#  Row(_c0=327, person_id=427, name='George Schreck', sex='male', date of birth='1974-07-22'),
#  Row(_c0=328, person_id=428, name='Meredith Valez', sex='female', date of birth='1986-12-13'),
#  Row(_c0=329, person_id=429, name='Charles Schlarbaum', sex='male', date of birth='1999-07-16'),
#  Row(_c0=330, person_id=430, name='Annis Benton', sex='female', date of birth='1974-03-27'),
#  Row(_c0=331, person_id=431, name='Larry Holben', sex='male', date of birth='2000-03-07'),
#  Row(_c0=332, person_id=432, name='Michael Miller', sex='male', date of birth='1954-11-29'),
#  Row(_c0=333, person_id=433, name='James Wong', sex='male', date of birth='1990-03-02'),
#  Row(_c0=334, person_id=434, name='Nancy Scott', sex='female', date of birth='1968-04-28'),
#  Row(_c0=335, person_id=435, name='Vicki Napier', sex='female', date of birth='1992-09-13'),
#  Row(_c0=336, person_id=436, name='Andrea Harden', sex='female', date of birth='1917-09-20'),
#  Row(_c0=337, person_id=437, name='Ivan Mccormick', sex='male', date of birth='2012-07-10'),
#  Row(_c0=338, person_id=438, name='Carla Romeo', sex='female', date of birth='1985-02-17'),
#  Row(_c0=339, person_id=439, name='Jerry Dorsey', sex='male', date of birth='1954-05-14'),
#  Row(_c0=340, person_id=440, name='Daniel Manning', sex='male', date of birth='1997-07-03'),
#  Row(_c0=341, person_id=441, name='Robert Constance', sex='male', date of birth='1964-09-17'),
#  Row(_c0=342, person_id=442, name='Julia Holloway', sex='female', date of birth='1977-08-19'),
#  Row(_c0=343, person_id=443, name='Tina Smith', sex='female', date of birth='1971-03-20'),
#  Row(_c0=344, person_id=444, name='Duane Carlton', sex='male', date of birth='1959-05-23'),
#  Row(_c0=345, person_id=445, name='Michael Lopez', sex='male', date of birth='1989-08-21'),
#  Row(_c0=346, person_id=446, name='Frank Simpkins', sex='male', date of birth='1994-08-19'),
#  Row(_c0=347, person_id=447, name='Robert Webster', sex='male', date of birth='1965-04-18'),
#  Row(_c0=348, person_id=448, name='Ashley Bagwell', sex='female', date of birth='1984-06-28'),
#  Row(_c0=349, person_id=449, name='Jeanette Hernandez', sex='female', date of birth='2037-01-30'),
#  Row(_c0=350, person_id=450, name='John Beil', sex='male', date of birth='2010-05-16'),
#  Row(_c0=351, person_id=451, name='Lloyd Dillard', sex='male', date of birth='1990-10-12'),
#  Row(_c0=352, person_id=452, name='Trevor Clark', sex='male', date of birth='2005-12-04'),
#  Row(_c0=353, person_id=453, name='Patricia Bagshaw', sex='female', date of birth='2018-01-05'),
#  Row(_c0=354, person_id=454, name='Mark Leon', sex='male', date of birth='1960-09-27'),
#  Row(_c0=355, person_id=455, name='Charles Poremski', sex='male', date of birth='1940-12-15'),
#  Row(_c0=356, person_id=456, name='Robert Schuler', sex='male', date of birth='2013-11-10'),
#  Row(_c0=357, person_id=457, name='Angel Dubose', sex='female', date of birth='1974-06-24'),
#  Row(_c0=358, person_id=458, name='Ronald Dixon', sex='male', date of birth='1972-01-09'),
#  Row(_c0=359, person_id=459, name='Troy Patterson', sex='male', date of birth='1944-06-30'),
#  Row(_c0=360, person_id=460, name='Richard Hernandez', sex='male', date of birth='1984-05-25'),
#  Row(_c0=361, person_id=461, name='Christy Dawson', sex='female', date of birth='1904-01-11'),
#  Row(_c0=362, person_id=462, name='Thomas Dorsey', sex='male', date of birth='1978-02-22'),
#  Row(_c0=363, person_id=463, name='Cynthia Nelson', sex='female', date of birth='2009-02-05'),
#  Row(_c0=364, person_id=464, name='Frank Curtin', sex='male', date of birth='2002-04-13'),
#  Row(_c0=365, person_id=465, name='Josephine Lindberg', sex='female', date of birth='20175-02-28'),
#  Row(_c0=366, person_id=466, name='Charles Filson', sex='male', date of birth='1963-11-26'),
#  Row(_c0=367, person_id=467, name='Candice Henderson', sex='female', date of birth='1975-11-16'),
#  Row(_c0=368, person_id=468, name='Patrick Mitchell', sex='male', date of birth='1982-01-18'),
#  Row(_c0=369, person_id=469, name='Mary Rush', sex='female', date of birth='1964-10-11'),
#  Row(_c0=370, person_id=470, name='Delphine Scaffidi', sex='female', date of birth='1974-11-12'),
#  Row(_c0=371, person_id=471, name='Anthony Harper', sex='male', date of birth='1977-03-04'),
#  Row(_c0=372, person_id=472, name='James Kraft', sex='male', date of birth='1988-08-12'),
#  Row(_c0=373, person_id=473, name='John Cantrell', sex='male', date of birth='1949-05-13'),
#  Row(_c0=374, person_id=474, name='Joseph Boatwright', sex='male', date of birth='1988-04-03'),
#  Row(_c0=375, person_id=475, name='Lizeth Merida', sex='female', date of birth='1992-09-13'),
#  Row(_c0=376, person_id=476, name='Linda Obrien', sex='female', date of birth='1987-09-21'),
#  Row(_c0=377, person_id=477, name='Michael Avila', sex='male', date of birth='1981-08-13'),
#  Row(_c0=378, person_id=478, name='Jack Edwards', sex='female', date of birth='1987-04-12'),
#  Row(_c0=379, person_id=479, name='John Alexander', sex='male', date of birth='2005-11-27'),
#  Row(_c0=380, person_id=480, name='Albert Guillory', sex='male', date of birth='2001-02-10'),
#  Row(_c0=381, person_id=481, name='Amber Kester', sex='female', date of birth='1995-01-14'),
#  Row(_c0=382, person_id=482, name='Jordan Cramer', sex='male', date of birth='2002-04-12'),
#  Row(_c0=383, person_id=483, name='David Davis', sex='male', date of birth='1973-08-06'),
#  Row(_c0=384, person_id=484, name='Howard Owens', sex='male', date of birth='1996-10-25'),
#  Row(_c0=385, person_id=485, name='James Kelly', sex='male', date of birth='1992-04-05'),
#  Row(_c0=386, person_id=486, name='Zelda Smith', sex='female', date of birth='1977-05-29'),
#  Row(_c0=387, person_id=487, name='Mary Mone', sex='female', date of birth='1959-05-07'),
#  Row(_c0=388, person_id=488, name='Beverly Bardon', sex='female', date of birth='1974-07-19'),
#  Row(_c0=389, person_id=489, name='Michelle Lamothe', sex='female', date of birth='2008-07-15'),
#  Row(_c0=390, person_id=490, name='Connie Lee', sex='female', date of birth='1961-08-25'),
#  Row(_c0=391, person_id=491, name='Jimmie Lodge', sex='male', date of birth='1984-03-05'),
#  Row(_c0=392, person_id=492, name='Richard Suits', sex='male', date of birth='2021-02-03'),
#  Row(_c0=393, person_id=493, name='Paul Kornegay', sex='male', date of birth='1956-03-26'),
#  Row(_c0=394, person_id=494, name='Daniel Summers', sex='male', date of birth='1967-02-03'),
#  Row(_c0=395, person_id=495, name='Joyce Rohrbacher', sex='female', date of birth='1978-03-25'),
#  Row(_c0=396, person_id=496, name='Hazel Valentine', sex='female', date of birth='1987-01-29'),
#  Row(_c0=397, person_id=497, name='Houston Bohn', sex='male', date of birth='1972-11-13'),
#  Row(_c0=398, person_id=498, name='Joseph Rosa', sex='male', date of birth='1998-09-25'),
#  Row(_c0=399, person_id=499, name='Luke Ruiz', sex='male', date of birth='1995-11-12'),
#  Row(_c0=400, person_id=500, name='Scott Carr', sex='male', date of birth='1972-08-26'),
#  Row(_c0=401, person_id=501, name='Issac Pellerin', sex='male', date of birth='1990-08-14'),
#  Row(_c0=402, person_id=502, name='Cassandra Chalfant', sex='female', date of birth='1958-05-01'),
#  Row(_c0=403, person_id=503, name='Deborah Souza', sex='female', date of birth='1999-01-06'),
#  Row(_c0=404, person_id=504, name='Celesta Swartz', sex='female', date of birth='1977-09-26'),
#  Row(_c0=405, person_id=505, name='Maria Bohanan', sex='female', date of birth='2022-10-23'),
#  Row(_c0=406, person_id=506, name='Della Warren', sex='female', date of birth='1996-09-25'),
#  Row(_c0=407, person_id=507, name='Amanda Hudman', sex='female', date of birth='1952-04-10'),
#  Row(_c0=408, person_id=508, name='Edward Sterling', sex='male', date of birth='1992-02-01'),
#  Row(_c0=409, person_id=509, name='Debra Nixon', sex='female', date of birth='20175-02-28'),
#  Row(_c0=410, person_id=510, name='Donald Kirkman', sex='male', date of birth='1982-09-05'),
#  Row(_c0=411, person_id=511, name='Vincent Masters', sex='male', date of birth='20175-02-28'),
#  Row(_c0=412, person_id=512, name='Ida Dickson', sex='female', date of birth='1983-07-13'),
#  Row(_c0=413, person_id=513, name='Rebecca Henderson', sex='female', date of birth='2016-05-06'),
#  Row(_c0=414, person_id=514, name='Richie Banks', sex='male', date of birth='2014-08-31'),
#  Row(_c0=415, person_id=515, name='Patrick Day', sex='male', date of birth='2010-12-22'),
#  Row(_c0=416, person_id=516, name='Florence Paci', sex='female', date of birth='1990-12-27'),
#  Row(_c0=417, person_id=517, name='Eva Gambrell', sex='female', date of birth='1956-11-03'),
#  Row(_c0=418, person_id=518, name='Dina Rhodes', sex='female', date of birth='1964-06-23'),
#  Row(_c0=419, person_id=519, name='Paula Savage', sex='female', date of birth='1982-03-07'),
#  Row(_c0=420, person_id=520, name='Carolyn Quintana', sex='female', date of birth='1958-01-01'),
#  Row(_c0=421, person_id=521, name='Steven Calvin', sex='male', date of birth='1975-05-18'),
#  Row(_c0=422, person_id=522, name='Beverly Ayon', sex='female', date of birth='1943-08-06'),
#  Row(_c0=423, person_id=523, name='Janette Tucker', sex='female', date of birth='2002-01-21'),
#  Row(_c0=424, person_id=524, name='Harriette Wilcox', sex='female', date of birth='1956-09-26'),
#  Row(_c0=425, person_id=525, name='Rhonda Schlarbaum', sex='female', date of birth='1967-09-15'),
#  Row(_c0=426, person_id=526, name='Sharon Ahrens', sex='female', date of birth='1981-12-28'),
#  Row(_c0=427, person_id=527, name='Ronald Robinson', sex='male', date of birth='1958-03-08'),
#  Row(_c0=428, person_id=528, name='Teresa Gambone', sex='female', date of birth='1940-03-25'),
#  Row(_c0=429, person_id=529, name='Linda Martinez', sex='female', date of birth='1996-08-17'),
#  Row(_c0=430, person_id=530, name='Richard Moore', sex='male', date of birth='1989-05-11'),
#  Row(_c0=431, person_id=531, name='Herman Pina', sex='male', date of birth='1963-10-08'),
#  Row(_c0=432, person_id=532, name='Daniel Stephens', sex='male', date of birth='1986-06-28'),
#  Row(_c0=433, person_id=533, name='Theodore Owens', sex='male', date of birth='1988-11-23'),
#  Row(_c0=434, person_id=534, name='Sarah Curry', sex='female', date of birth='2007-04-16'),
#  Row(_c0=435, person_id=535, name='Sheila Odle', sex='female', date of birth='1976-05-27'),
#  Row(_c0=436, person_id=536, name='Terry Hancher', sex='male', date of birth='2023-07-03'),
#  Row(_c0=437, person_id=537, name='Michael Darby', sex='male', date of birth='1978-01-24'),
#  Row(_c0=438, person_id=538, name='Janet Bartlett', sex='female', date of birth='1941-03-29'),
#  Row(_c0=439, person_id=539, name='Donna Streater', sex='female', date of birth='2000-05-27'),
#  Row(_c0=440, person_id=540, name='Agnes Slater', sex='female', date of birth='1982-03-16'),
#  Row(_c0=441, person_id=541, name='Melinda Doyle', sex='female', date of birth='1979-05-24'),
#  Row(_c0=442, person_id=542, name='Nancy Garfield', sex='female', date of birth='1965-03-26'),
#  Row(_c0=443, person_id=543, name='Theresa Higgins', sex='female', date of birth='1992-10-04'),
#  Row(_c0=444, person_id=544, name='Beth Obrien', sex='female', date of birth='1948-04-18'),
#  Row(_c0=445, person_id=545, name='Irma Diaz', sex='female', date of birth='2018-09-06'),
#  Row(_c0=446, person_id=546, name='Shaneka Roberts', sex='female', date of birth='1982-08-21'),
#  Row(_c0=447, person_id=547, name='Timothy Fisher', sex='male', date of birth='2009-10-21'),
#  Row(_c0=448, person_id=548, name='Ann Neidig', sex='female', date of birth='2019-04-24'),
#  Row(_c0=449, person_id=549, name='Tony Tetzloff', sex='male', date of birth='2009-07-03'),
#  Row(_c0=450, person_id=550, name='Lanny Everitt', sex='male', date of birth='1961-06-07'),
#  Row(_c0=451, person_id=551, name='Darlene Merson', sex='female', date of birth='1966-04-17'),
#  Row(_c0=452, person_id=552, name='Carl Butler', sex='male', date of birth='1941-11-18'),
#  Row(_c0=453, person_id=553, name='Anthony Guererro', sex='male', date of birth='2012-05-29'),
#  Row(_c0=454, person_id=554, name='Michael Julian', sex='male', date of birth='1985-01-15'),
#  Row(_c0=455, person_id=555, name='Estella Coleman', sex='female', date of birth='1953-12-16'),
#  Row(_c0=456, person_id=556, name='Daniela Evans', sex='female', date of birth='1942-06-15'),
#  Row(_c0=457, person_id=557, name='Sandra Lowe', sex='female', date of birth='1994-09-03'),
#  Row(_c0=458, person_id=558, name='Misty Holmes', sex='female', date of birth='1948-05-13'),
#  Row(_c0=459, person_id=559, name='Jeffrey Vanduyne', sex='male', date of birth='1989-04-01'),
#  Row(_c0=460, person_id=560, name='Charlotte Mcfarling', sex='female', date of birth='1967-06-09'),
#  Row(_c0=461, person_id=561, name='Stephanie Minihane', sex='female', date of birth='1982-10-10'),
#  Row(_c0=462, person_id=562, name='Richard Lettieri', sex='male', date of birth='1968-06-08'),
#  Row(_c0=463, person_id=563, name='Ila Wittels', sex='female', date of birth='1980-09-30'),
#  Row(_c0=464, person_id=564, name='Mary Juarez', sex='female', date of birth='1988-08-26'),
#  Row(_c0=465, person_id=565, name='Dennis Nye', sex='male', date of birth='2002-02-12'),
#  Row(_c0=466, person_id=566, name='Jacques Maples', sex='male', date of birth='1989-07-21'),
#  Row(_c0=467, person_id=567, name='William Sylvestre', sex='male', date of birth='1999-04-17'),
#  Row(_c0=468, person_id=568, name='Mary Dolezal', sex='female', date of birth='1980-01-09'),
#  Row(_c0=469, person_id=569, name='Lawrence Castillo', sex='male', date of birth='1991-03-23'),
#  Row(_c0=470, person_id=570, name='Christopher Gonzalez', sex='male', date of birth='1964-09-16'),
#  Row(_c0=471, person_id=571, name='Edward Olson', sex='male', date of birth='1974-03-29'),
#  Row(_c0=472, person_id=572, name='Aaron Thomas', sex='male', date of birth='1998-05-31'),
#  Row(_c0=473, person_id=573, name='Clifton Hoover', sex='male', date of birth='1974-03-04'),
#  Row(_c0=474, person_id=574, name='Amanda Speight', sex='female', date of birth='1967-09-24'),
#  Row(_c0=475, person_id=575, name='William Fontenot', sex='male', date of birth='1980-07-02'),
#  Row(_c0=476, person_id=576, name='Carlos Cook', sex='male', date of birth='1963-01-19'),
#  Row(_c0=477, person_id=577, name='Shirley Davis', sex='female', date of birth='1970-08-29'),
#  Row(_c0=478, person_id=578, name='Diane Henderson', sex='female', date of birth='1965-01-09'),
#  Row(_c0=479, person_id=579, name='Michael Brown', sex='male', date of birth='1948-04-26'),
#  Row(_c0=480, person_id=580, name='Harley Crist', sex='male', date of birth='1992-09-03'),
#  Row(_c0=481, person_id=581, name='Jose Wilson', sex='male', date of birth='1975-08-25'),
#  Row(_c0=482, person_id=582, name='Lee Jensen', sex='male', date of birth='1953-01-30'),
#  Row(_c0=483, person_id=583, name='Charles Lopez', sex='male', date of birth='1976-06-01'),
#  Row(_c0=484, person_id=584, name='Mary Moore', sex='female', date of birth='1979-05-15'),
#  Row(_c0=485, person_id=585, name='Deborah Sanchez', sex='female', date of birth='1986-06-25'),
#  Row(_c0=486, person_id=586, name='Mark Barton', sex='male', date of birth='1989-11-11'),
#  Row(_c0=487, person_id=587, name='Don Thurn', sex='male', date of birth='1963-09-04'),
#  Row(_c0=488, person_id=588, name='Terry Tanzosch', sex='male', date of birth='1973-07-09'),
#  Row(_c0=489, person_id=589, name='Robert Blackburn', sex='male', date of birth='1963-12-24'),
#  Row(_c0=490, person_id=590, name='Sarah Sullinger', sex='female', date of birth='1989-05-17'),
#  Row(_c0=491, person_id=591, name='Kerry Brentley', sex='male', date of birth='1955-12-03'),
#  Row(_c0=492, person_id=592, name='Ruth Ferrufino', sex='female', date of birth='1980-04-29'),
#  Row(_c0=493, person_id=593, name='Duane Williams', sex='male', date of birth='1986-08-22'),
#  Row(_c0=494, person_id=594, name='Tara Underwood', sex='female', date of birth='1990-03-23'),
#  Row(_c0=495, person_id=595, name='Vanessa Allen', sex='female', date of birth='1963-11-05'),
#  Row(_c0=496, person_id=596, name='John Leclair', sex='male', date of birth='1944-03-11'),
#  Row(_c0=497, person_id=597, name='Merry Davis', sex='female', date of birth='1994-02-22'),
#  Row(_c0=498, person_id=598, name='Janice Tyson', sex='female', date of birth='2010-09-26'),
#  Row(_c0=499, person_id=599, name='Leo Heimbach', sex='male', date of birth='1954-07-27'),
#  Row(_c0=500, person_id=600, name='Jennifer Porter', sex='female', date of birth='1993-08-27'),
#  Row(_c0=501, person_id=601, name='Deloris Velo', sex='female', date of birth='1984-01-07'),
#  Row(_c0=502, person_id=602, name='Donna Wilbur', sex='female', date of birth='1987-10-25'),
#  Row(_c0=503, person_id=603, name='Janice Jackson', sex='female', date of birth='1992-10-23'),
#  Row(_c0=504, person_id=604, name='Polly Curley', sex='female', date of birth='1982-09-05'),
#  Row(_c0=505, person_id=605, name='John Mcintire', sex='male', date of birth='2014-11-25'),
#  Row(_c0=506, person_id=606, name='Curtis Iversen', sex='male', date of birth='2018-04-28'),
#  Row(_c0=507, person_id=607, name='Susan Whipple', sex='female', date of birth='2006-04-03'),
#  Row(_c0=508, person_id=608, name='Andrew Alexander', sex='male', date of birth='2015-01-31'),
#  Row(_c0=509, person_id=609, name='Clarence Singleton', sex='male', date of birth='2001-05-26'),
#  Row(_c0=510, person_id=610, name='Joe Gadison', sex='male', date of birth='1978-02-17'),
#  Row(_c0=511, person_id=611, name='Mercedes Komara', sex='female', date of birth='1947-06-06'),
#  Row(_c0=512, person_id=612, name='Alvin Henderson', sex='male', date of birth='2042-02-01'),
#  Row(_c0=513, person_id=613, name='Ruth Clark', sex='female', date of birth='1966-02-14'),
#  Row(_c0=514, person_id=614, name='Raymond Dickinson', sex='male', date of birth='1946-07-30'),
#  Row(_c0=515, person_id=615, name='Carlos Novak', sex='male', date of birth='1953-11-08'),
# ...
#  Row(_c0=830, person_id=930, name='William Nevels', sex='male', date of birth='1960-09-17'),
#  Row(_c0=831, person_id=931, name='Buford Carney', sex='male', date of birth='1968-03-03'),
#  Row(_c0=832, person_id=932, name='Virginia Brussel', sex='female', date of birth='1975-09-21'),
#  Row(_c0=833, person_id=933, name='Yolanda Hippler', sex='female', date of birth='1982-07-19'),
#  Row(_c0=834, person_id=934, name='Frank Black', sex='male', date of birth='1974-03-26'),
#  Row(_c0=835, person_id=935, name='April Flowers', sex='female', date of birth='1970-02-18'),
#  Row(_c0=836, person_id=936, name='Lori Mayfield', sex='female', date of birth='1986-07-22'),
#  Row(_c0=837, person_id=937, name='Vernon Brown', sex='male', date of birth='1966-07-16'),
#  Row(_c0=838, person_id=938, name='Kay Gonzalez', sex='female', date of birth='1984-07-28'),
#  Row(_c0=839, person_id=939, name='Mark Mahoney', sex='male', date of birth='1951-10-13'),
#  Row(_c0=840, person_id=940, name='Rebecca Husseini', sex='female', date of birth='2016-11-01'),
#  Row(_c0=841, person_id=941, name='John Madewell', sex='male', date of birth='1977-03-04'),
#  Row(_c0=842, person_id=942, name='Wendy Mccutcheon', sex='female', date of birth='2000-06-06'),
#  Row(_c0=843, person_id=943, name='Ashley Jenkins', sex='female', date of birth='1965-01-08'),
#  Row(_c0=844, person_id=944, name='Salina Jones', sex='female', date of birth='1962-05-11'),
#  Row(_c0=845, person_id=945, name='Martin Carson', sex='male', date of birth='1961-01-02'),
#  Row(_c0=846, person_id=946, name='Leonard Cokley', sex='male', date of birth='1986-06-07'),
#  Row(_c0=847, person_id=947, name='Norman Torres', sex='female', date of birth='1983-08-29'),
#  Row(_c0=848, person_id=948, name='Caryn Sixon', sex='female', date of birth='1976-03-08'),
#  Row(_c0=849, person_id=949, name='Brandon Kittrell', sex='male', date of birth='1961-09-03'),
#  Row(_c0=850, person_id=950, name='Frances Floto', sex='female', date of birth='1964-03-05'),
#  Row(_c0=851, person_id=951, name='Patrick Beyer', sex='male', date of birth='1954-05-27'),
#  Row(_c0=852, person_id=952, name='Sarah Henderson', sex='female', date of birth='1952-12-20'),
#  Row(_c0=853, person_id=953, name='Julia Howell', sex=None, date of birth='1929-05-30'),
#  Row(_c0=854, person_id=954, name='Agnes Cooper', sex='female', date of birth='1992-10-05'),
#  Row(_c0=855, person_id=955, name='James Ellingham', sex='male', date of birth='2010-01-20'),
#  Row(_c0=856, person_id=956, name='Kenneth Toliver', sex='male', date of birth='1965-10-20'),
#  Row(_c0=857, person_id=957, name='Frankie Cole', sex='female', date of birth='2021-10-12'),
#  Row(_c0=858, person_id=958, name='Roger Smith', sex='male', date of birth='1969-04-14'),
#  Row(_c0=859, person_id=959, name='Leo Campbell', sex='male', date of birth='2016-03-19'),
#  Row(_c0=860, person_id=960, name='Tanya Rayborn', sex='female', date of birth='1979-09-18'),
#  Row(_c0=861, person_id=961, name='Mary Luna', sex='female', date of birth='1985-03-04'),
#  Row(_c0=862, person_id=962, name='Ezekiel Esquivel', sex='male', date of birth='2023-12-17'),
#  Row(_c0=863, person_id=963, name='Alice Howzell', sex='female', date of birth='1990-11-18'),
#  Row(_c0=864, person_id=964, name='Jennifer Sanchez', sex='female', date of birth='1971-12-26'),
#  Row(_c0=865, person_id=965, name='Kathleen Salazar', sex=None, date of birth='1971-08-10'),
#  Row(_c0=866, person_id=966, name='John Knowles', sex='male', date of birth='1977-08-05'),
#  Row(_c0=867, person_id=967, name='Laura Webb', sex='female', date of birth='1972-04-17'),
#  Row(_c0=868, person_id=968, name='Christian Harris', sex='male', date of birth='2010-06-05'),
#  Row(_c0=869, person_id=969, name='Fred Elliott', sex='male', date of birth='1991-05-07'),
#  Row(_c0=870, person_id=970, name='Millicent Cooper', sex='female', date of birth='2000-12-02'),
#  Row(_c0=871, person_id=971, name='Henrietta Blanchard', sex='female', date of birth='1984-02-01'),
#  Row(_c0=872, person_id=972, name='Cruz Mccune', sex='male', date of birth='2011-10-28'),
#  Row(_c0=873, person_id=973, name='John Hayes', sex=None, date of birth='1958-09-15'),
#  Row(_c0=874, person_id=974, name='Jamie Smith', sex='female', date of birth='1984-08-15'),
#  Row(_c0=875, person_id=975, name='Ralph Walcott', sex='male', date of birth='1989-07-29'),
#  Row(_c0=876, person_id=976, name='Adam Gilliam', sex='male', date of birth='1961-09-30'),
#  Row(_c0=877, person_id=977, name='Sean Cortez', sex='male', date of birth='1952-01-16'),
#  Row(_c0=878, person_id=978, name='Michael Gragg', sex='male', date of birth='1987-04-13'),
#  Row(_c0=879, person_id=979, name='Pamela Cuchares', sex='female', date of birth='1986-04-23'),
#  Row(_c0=880, person_id=980, name='Mary Kindl', sex='female', date of birth='1984-02-01'),
#  Row(_c0=881, person_id=981, name='Ryan Wilson', sex='female', date of birth='2006-12-30'),
#  Row(_c0=882, person_id=982, name='Emma Hogue', sex='female', date of birth='1995-05-29'),
#  Row(_c0=883, person_id=983, name='Clara Kowalski', sex='female', date of birth='1988-09-23'),
#  Row(_c0=884, person_id=984, name='Bobby Wetherington', sex='male', date of birth='1973-08-02'),
#  Row(_c0=885, person_id=985, name='Timothy Harman', sex='male', date of birth='2002-10-16'),
#  Row(_c0=886, person_id=986, name='Annie Templeton', sex='female', date of birth='1939-10-03'),
#  Row(_c0=887, person_id=987, name='Sylvia Williams', sex='female', date of birth='1962-02-07'),
#  Row(_c0=888, person_id=988, name='Wesley Benscoter', sex='male', date of birth='1987-09-12'),
#  Row(_c0=889, person_id=989, name='Carrie Washington', sex='female', date of birth='2012-03-09'),
#  Row(_c0=890, person_id=990, name='Gerard Coleman', sex='male', date of birth='1967-05-05'),
#  Row(_c0=891, person_id=991, name='Steven Ibarra', sex='male', date of birth='1963-07-01'),
#  Row(_c0=892, person_id=992, name='Kimberly Chavez', sex='female', date of birth='2002-03-07'),
#  Row(_c0=893, person_id=993, name='Shirley Parado', sex='female', date of birth='1993-06-27'),
#  Row(_c0=894, person_id=994, name='Graham Wikoff', sex='male', date of birth='1989-05-29'),
#  Row(_c0=895, person_id=995, name='Dana Zediker', sex='female', date of birth='1974-04-15'),
#  Row(_c0=896, person_id=996, name='William Saddler', sex='male', date of birth='1940-10-19'),
#  Row(_c0=897, person_id=997, name='Mary Rice', sex='female', date of birth='1974-10-26'),
#  Row(_c0=898, person_id=998, name='Hector Christian', sex='male', date of birth='1995-11-24'),
#  Row(_c0=899, person_id=999, name='Yung Evans', sex='female', date of birth='1958-12-27'),
#  Row(_c0=900, person_id=1000, name='Stephen Bateman', sex='male', date of birth='1989-02-08'),
#  Row(_c0=901, person_id=1001, name='Jack Fletcher', sex='male', date of birth='1977-04-03'),
#  Row(_c0=902, person_id=1002, name='Michael Lokken', sex='male', date of birth='1954-06-03'),
#  Row(_c0=903, person_id=1003, name='Nadine Spain', sex='female', date of birth='1972-03-30'),
#  Row(_c0=904, person_id=1004, name='Norma Merrick', sex='female', date of birth='1934-07-22'),
#  Row(_c0=905, person_id=1005, name='Charles Hernandez', sex='male', date of birth='1963-02-12'),
#  Row(_c0=906, person_id=1006, name='John Hunt', sex='male', date of birth='1977-11-13'),
#  Row(_c0=907, person_id=1007, name='Charles Harman', sex='male', date of birth='1973-02-23'),
#  Row(_c0=908, person_id=1008, name='Lee Baylor', sex='female', date of birth='1944-03-14'),
#  Row(_c0=909, person_id=1009, name='Richard Osborn', sex='male', date of birth='2006-12-07'),
#  Row(_c0=910, person_id=1010, name='Brenda Lorenz', sex='female', date of birth='1957-05-10'),
#  Row(_c0=911, person_id=1011, name='Renee Lopez', sex='female', date of birth='1966-12-02'),
#  Row(_c0=912, person_id=1012, name='Jean Aguilar', sex='female', date of birth='1984-12-31'),
#  Row(_c0=913, person_id=1013, name='Amanda Ribeiro', sex='female', date of birth='1986-12-12'),
#  Row(_c0=914, person_id=1014, name='Christina Burns', sex='female', date of birth='1975-07-18'),
#  Row(_c0=915, person_id=1015, name='Allen Lowery', sex='male', date of birth='1973-04-02'),
#  Row(_c0=916, person_id=1016, name='Laura Martelli', sex='female', date of birth='1977-11-24'),
#  Row(_c0=917, person_id=1017, name='Phyllis Castanon', sex='female', date of birth='1987-09-12'),
#  Row(_c0=918, person_id=1018, name='Chris Bonneville', sex='male', date of birth='1972-12-03'),
#  Row(_c0=919, person_id=1019, name='Cecilia Adams', sex='female', date of birth='1946-12-27'),
#  Row(_c0=920, person_id=1020, name='Sidney Corey', sex='male', date of birth='1969-06-22'),
#  Row(_c0=921, person_id=1021, name='Tracy Drain', sex='female', date of birth='1971-10-12'),
#  Row(_c0=922, person_id=1022, name='Teresa Lewis', sex='female', date of birth='2014-09-12'),
#  Row(_c0=923, person_id=1023, name='Merle Cahill', sex='male', date of birth='1994-09-14'),
#  Row(_c0=924, person_id=1024, name='Johnnie Camacho', sex='female', date of birth='2002-05-02'),
#  Row(_c0=925, person_id=1025, name='Yvonne Malone', sex='female', date of birth='1966-06-30'),
#  Row(_c0=926, person_id=1026, name='Thomas Brown', sex='male', date of birth='1995-09-26'),
#  Row(_c0=927, person_id=1027, name='Shanda Mccaffrey', sex='female', date of birth='1984-05-13'),
#  Row(_c0=928, person_id=1028, name='Sarah Wideman', sex='female', date of birth='1984-07-29'),
#  Row(_c0=929, person_id=1029, name='Robert Newkirk', sex='male', date of birth='1993-01-24'),
#  Row(_c0=930, person_id=1030, name='Barbara Wolfe', sex='female', date of birth='2007-06-21'),
#  Row(_c0=931, person_id=1031, name='Scotty Santos', sex='male', date of birth='1972-11-13'),
#  Row(_c0=932, person_id=1032, name='Louise Fowler', sex='female', date of birth='2031-03-02'),
#  Row(_c0=933, person_id=1033, name='George Arthur', sex='male', date of birth='1977-03-17'),
#  Row(_c0=934, person_id=1034, name='Edward Pippin', sex='male', date of birth='2037-04-02'),
#  Row(_c0=935, person_id=1035, name='Shelley James', sex='female', date of birth='1957-10-09'),
#  Row(_c0=936, person_id=1036, name='Arlene Aragon', sex='female', date of birth='1969-07-28'),
#  Row(_c0=937, person_id=1037, name='Michael Jones', sex='male', date of birth='2004-06-07'),
#  Row(_c0=938, person_id=1038, name='James Elliott', sex='male', date of birth='1944-11-29'),
#  Row(_c0=939, person_id=1039, name='Aileen Glaser', sex='female', date of birth='1982-08-18'),
#  Row(_c0=940, person_id=1040, name='Carmen Lewis', sex='female', date of birth='2012-01-15'),
#  Row(_c0=941, person_id=1041, name='Linda Decker', sex='female', date of birth='1973-10-22'),
#  Row(_c0=942, person_id=1042, name='Christopher Merideth', sex='male', date of birth='2009-06-18'),
#  Row(_c0=943, person_id=1043, name='Carol Walker', sex='female', date of birth='1983-08-10'),
#  Row(_c0=944, person_id=1044, name='Kirk Stump', sex='male', date of birth='2004-06-25'),
#  Row(_c0=945, person_id=1045, name='Kristy Wilson', sex='female', date of birth='1985-05-25'),
#  Row(_c0=946, person_id=1046, name='Charlotte Short', sex='female', date of birth='1937-04-08'),
#  Row(_c0=947, person_id=1047, name='Wayne Benjamin', sex='male', date of birth='1963-07-25'),
#  Row(_c0=948, person_id=1048, name='Ruth Hull', sex='female', date of birth='1993-08-03'),
#  Row(_c0=949, person_id=1049, name='Lawrence Hensel', sex='male', date of birth='2009-07-10'),
#  Row(_c0=950, person_id=1050, name='Leon Seman', sex='male', date of birth='1986-07-04'),
#  Row(_c0=951, person_id=1051, name='Krystal Hodges', sex='female', date of birth='2022-05-17'),
#  Row(_c0=952, person_id=1052, name='Julia Spivey', sex='female', date of birth='2003-10-07'),
#  Row(_c0=953, person_id=1053, name='Martin Bylsma', sex='male', date of birth='1980-05-07'),
#  Row(_c0=954, person_id=1054, name='Jose Jacobs', sex='male', date of birth='1980-12-11'),
#  Row(_c0=955, person_id=1055, name='Antoinette Martin', sex='female', date of birth='2003-07-29'),
#  Row(_c0=956, person_id=1056, name='Kathyrn Ivory', sex='female', date of birth='1983-01-09'),
#  Row(_c0=957, person_id=1057, name='Kimberly Madore', sex='female', date of birth='1982-04-27'),
#  Row(_c0=958, person_id=1058, name='Raul Jordon', sex='male', date of birth='2011-12-07'),
#  Row(_c0=959, person_id=1059, name='Abdul Faust', sex='male', date of birth='1962-12-04'),
#  Row(_c0=960, person_id=1060, name='Mary Mcintosh', sex='female', date of birth='1961-01-11'),
#  Row(_c0=961, person_id=1061, name='Mary Ritter', sex='female', date of birth='1966-03-03'),
#  Row(_c0=962, person_id=1062, name='Tamra Gardner', sex='female', date of birth='2011-04-15'),
#  Row(_c0=963, person_id=1063, name='Thomas Henry', sex='male', date of birth='2003-06-01'),
#  Row(_c0=964, person_id=1064, name='Janet Beek', sex='female', date of birth='1987-03-22'),
#  Row(_c0=965, person_id=1065, name='Joseph Williams', sex='male', date of birth='2015-04-21'),
#  Row(_c0=966, person_id=1066, name='Deborah Hull', sex='female', date of birth='1966-09-08'),
#  Row(_c0=967, person_id=1067, name='Shelby Cline', sex='female', date of birth='2023-01-19'),
#  Row(_c0=968, person_id=1068, name='Luther Cullen', sex='male', date of birth='1975-08-29'),
#  Row(_c0=969, person_id=1069, name='Robert Cressman', sex='male', date of birth='2006-12-06'),
#  Row(_c0=970, person_id=1070, name='Fern Freeman', sex='female', date of birth='20175-02-28'),
#  Row(_c0=971, person_id=1071, name='Curtis Mason', sex='male', date of birth='20175-02-28'),
#  Row(_c0=972, person_id=1072, name='Nancy Musser', sex='female', date of birth='1969-08-28'),
#  Row(_c0=973, person_id=1073, name='Frederick Barnes', sex='male', date of birth='1994-09-29'),
#  Row(_c0=974, person_id=1074, name='Nancy Williams', sex='female', date of birth='1948-09-16'),
#  Row(_c0=975, person_id=1075, name='Daniel Mata', sex='male', date of birth='2008-06-20'),
#  Row(_c0=976, person_id=1076, name='George Aquirre', sex='male', date of birth='2003-08-20'),
#  Row(_c0=977, person_id=1077, name='Kathy Neal', sex='female', date of birth='2015-09-22'),
#  Row(_c0=978, person_id=1078, name='Elizabeth Wene', sex='female', date of birth='1978-06-29'),
#  Row(_c0=979, person_id=1079, name='Cynthia Kass', sex='female', date of birth='1965-02-19'),
#  Row(_c0=980, person_id=1080, name='John Blaylock', sex='male', date of birth='1987-10-28'),
#  Row(_c0=981, person_id=1081, name='David Haynes', sex='male', date of birth='1980-10-07'),
#  Row(_c0=982, person_id=1082, name='Elizabeth Guzman', sex='female', date of birth='1943-01-10'),
#  Row(_c0=983, person_id=1083, name='Jason Oullette', sex='male', date of birth='1990-12-16'),
#  Row(_c0=984, person_id=1084, name='John Spadaro', sex='male', date of birth='1998-04-22'),
#  Row(_c0=985, person_id=1085, name='Veta Ezzo', sex='female', date of birth='2001-10-06'),
#  Row(_c0=986, person_id=1086, name='Marie Sheridan', sex='female', date of birth='1988-06-29'),
#  Row(_c0=987, person_id=1087, name='Richard Garcia', sex='male', date of birth='1994-05-22'),
#  Row(_c0=988, person_id=1088, name='Erasmo Crowder', sex='male', date of birth='2007-07-04'),
#  Row(_c0=989, person_id=1089, name='Tammie Cruz', sex='female', date of birth='1989-04-04'),
#  Row(_c0=990, person_id=1090, name='Wendy Giacchino', sex='female', date of birth='2009-09-13'),
#  Row(_c0=991, person_id=1091, name='Nicholas Campbell', sex='male', date of birth='1984-11-25'),
#  Row(_c0=992, person_id=1092, name='Irmgard Brown', sex='female', date of birth='1977-09-11'),
#  Row(_c0=993, person_id=1093, name='Julia Lyons', sex='female', date of birth='1989-08-20'),
#  Row(_c0=994, person_id=1094, name='Andrea Sykes', sex='female', date of birth='1988-04-29'),
#  Row(_c0=995, person_id=1095, name='Hal Groves', sex='male', date of birth='1981-04-24'),
#  Row(_c0=996, person_id=1096, name='Jovita Murray', sex='female', date of birth='2010-05-05'),
#  Row(_c0=997, person_id=1097, name='Nila Ford', sex='female', date of birth='1961-03-07'),
#  Row(_c0=998, person_id=1098, name='Kristina Herrera', sex='female', date of birth='1966-11-10'),
#  Row(_c0=999, person_id=1099, name='Patricia Hicks', sex='female', date of birth='1957-06-30'),
#  ...]

# %%
people_df.show()
# Out:
# +---+---------+-----------------+------+-------------+
# |_c0|person_id|             name|   sex|date of birth|
# +---+---------+-----------------+------+-------------+
# |  0|      100|   Penelope Lewis|female|   1990-08-31|
# |  1|      101|    David Anthony|  male|   1971-10-14|
# |  2|      102|        Ida Shipp|female|   1962-05-24|
# |  3|      103|     Joanna Moore|female|   2017-03-10|
# |  4|      104|   Lisandra Ortiz|female|   2020-08-05|
# |  5|      105|    David Simmons|  male|   1999-12-30|
# |  6|      106|    Edward Hudson|  male|   1983-05-09|
# |  7|      107|     Albert Jones|  male|   1990-09-13|
# |  8|      108| Leonard Cavender|  male|   1958-08-08|
# |  9|      109|   Everett Vadala|  male|   2005-05-24|
# | 10|      110| Freddie Claridge|  male|   2002-05-07|
# | 11|      111|Annabelle Rosseau|female|   1989-07-13|
# | 12|      112|    Eulah Emanuel|female|   1976-01-19|
# | 13|      113|       Shaun Love|  male|   1970-05-26|
# | 14|      114|Alejandro Brennan|  male|   1980-12-22|
# | 15|      115|Robert Mcreynolds|  male|   1973-12-27|
# | 16|      116|   Carla Spickard|female|   1985-06-13|
# | 17|      117|Florence Eberhart|female|   2024-06-01|
# | 18|      118|     Tina Gaskins|female|   1966-12-05|
# | 19|      119| Florence Mulhern|female|   1959-05-31|
# +---+---------+-----------------+------+-------------+
# only showing top 20 rows

# %%
print(people_df.printSchema())
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- person_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- sex: string (nullable = true)
#  |-- date of birth: string (nullable = true)
#
# None
